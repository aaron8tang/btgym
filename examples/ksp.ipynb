# %%
from btgym import BTgymEnv
from gym import spaces

# Handy function:
def under_the_hood(env):
    """Shows environment internals."""
    for attr in ['dataset','strategy','engine','renderer','network_address']:
        print ('\nEnv.{}: {}'.format(attr, getattr(env, attr)))

    for params_name, params_dict in env.params.items():
        print('\nParameters [{}]: '.format(params_name))
        for key, value in params_dict.items():
            print('{} : {}'.format(key,value))

# %%
MyEnvironment = BTgymEnv(filename='../examples/data/DAT_ASCII_EURUSD_M1_2016.csv',
                         
                     # Dataset and single random episode related parameters:
                         
                         # We start trading on mondays, thuesdays and wednesdays:
                         start_weekdays=[0, 1, 2],
                         # Want total episode duration to be no more than 1 day 23h 55min:
                         episode_duration={'days': 1, 'hours': 23, 'minutes': 55},
                         # Want to start every episode at the begiining of the day:
                         start_00=True,
                         
                     # Broker and trade realted:
                         
                         # Set initial capital:
                         start_cash=100,
                         # Set broker commission as 0.2% of operation value:
                         broker_commission=0.002,
                         # We use fixed stake of size 10:
                         fixed_stake=10,
                         # We want stop episode if 30% of initial capital is lost:
                         drawdown_call=30,
                         
                     # RL environment related parameters:
                         
                         # Set observation shape. By convention, first dimension 
                         # is time embedding dimensionality;
                         # that's basically means we get sequence of 30 last  
                         # [o,h,l,c] candels as our one-step environment observation:
                         
                         state_shape=dict(raw=spaces.Box(low=0,high=1,shape=(30,4))),
                                          
                         # BTgym uses multi-modal observation space which is basically dictionary
                         # consisting of simple gym spaces (Box, discrete, etc.)
                         # For the built-in `raw_state` setting high and low is dummy, because
                         # environment will infer values from entire dataset statistic.
                         
                     # Other parameters:
                         
                         # Network port to use; note that using multiply environments at once reqires expliciltly
                         # setting different ports to avoid meesing up. If your jupyter kernel suddenly dies
                         # when running new environment - that's may be because of port conflict,
                         # or 'previous' environment instance (client-side) is still running.
                         # Don't panic, just clear up and restart kernel,
                         # or use env.close() to shut down all the services.
                         port=5555,
                         # Data-server port to use, same as above apply:
                         #data_port=4600,
                         # Be chatty: settting this to 1 makes environment report what's going on;
                         # 2 is for debugging, dumps out a lot of data:
                         verbose=1,)

# Eyeball configuration:
under_the_hood(MyEnvironment)

done = False 

o = MyEnvironment.reset()

while not done: 
    action = MyEnvironment.action_space.sample() # random action
    obs, reward, done, info = MyEnvironment.step(action) 
    print('ACTION: {}\nREWARD: {}\nINFO: {}'.format(action, reward, info))
    
MyEnvironment.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# [2018-09-16 09:33:29.184234] INFO: BTgymAPIshell_0: Base Dataset class used.
# [2018-09-16 09:33:29.192330] INFO: BTgymAPIshell_0: Connecting data_server...
# [2018-09-16 09:33:29.314379] INFO: BTgymDataServer_0: PID: 2855
# [2018-09-16 09:33:30.285333] INFO: SimpleDataSet_0: Loaded 372678 records from <../examples/data/DAT_ASCII_EURUSD_M1_2016.csv>.
# [2018-09-16 09:33:30.464277] INFO: SimpleDataSet_0: Data summary:
#                 open           high            low          close    volume
# count  372678.000000  372678.000000  372678.000000  372678.000000  372678.0
# mean        1.107109       1.107198       1.107019       1.107108       0.0
# std         0.024843       0.024840       0.024847       0.024844       0.0
# min         1.035250       1.035470       1.035220       1.035220       0.0
# 25%         1.092140       1.092230       1.092040       1.092140       0.0
# 50%         1.113530       1.113610       1.113450       1.113530       0.0
# 75%         1.124710       1.124780       1.124630       1.124710       0.0
# max         1.161440       1.161600       1.160770       1.161450       0.0
# [2018-09-16 09:33:30.479461] INFO: BTgymAPIshell_0: ...done.
# [2018-09-16 09:33:30.487413] INFO: BTgymAPIshell_0: Base Cerebro class used. Base Strategy class used.
# [2018-09-16 09:33:30.497816] INFO: BTgymAPIshell_0: Inferring `state[raw]` high/low values form dataset: 1.035220 / 1.161600.
# [2018-09-16 09:33:30.572879] INFO: BTgymServer_0: PID: 2870
# [2018-09-16 09:33:31.563815] INFO: BTgymAPIshell_0: Server started, pinging tcp://127.0.0.1:5555 ...
# [2018-09-16 09:33:31.582060] INFO: BTgymAPIshell_0: Server seems ready with response: <{'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}>
# [2018-09-16 09:33:31.587444] INFO: BTgymAPIshell_0: Environment is ready.
#
# Env.dataset: <btgym.datafeed.derivative.BTgymDataset object at 0x7f9616418668>
#
# Env.strategy: <class 'btgym.strategy.base.BTgymBaseStrategy'>
#
# Env.engine: <backtrader.cerebro.Cerebro object at 0x7f9616418b70>
#
# Env.renderer: <btgym.rendering.renderer.BTgymRendering object at 0x7f9617452d68>
#
# Env.network_address: tcp://127.0.0.1:5555
#
# Parameters [engine]:
# start_cash : 100
# broker_commission : 0.002
# fixed_stake : 10
#
# Parameters [dataset]:
# filename : None
# sep : ;
# header : 0
# index_col : 0
# parse_dates : True
# names : ['open', 'high', 'low', 'close', 'volume']
# timeframe : 1
# datetime : 0
# open : 1
# high : 2
# low : 3
# close : 4
# volume : -1
# openinterest : -1
# sample_duration : {'days': 1, 'hours': 23, 'minutes': 55}
# start_weekdays : [0, 1, 2]
# start_00 : True
# time_gap : {'days': 0, 'hours': 6}
# expanding : False
# test_period : {'days': 0, 'hours': 0, 'minutes': 0}
#
# Parameters [strategy]:
# state_shape : {'raw': Box(30, 4)}
# cash_name : default_cash
# asset_names : ['default_asset']
# start_cash : None
# commission : None
# leverage : 1.0
# gamma : 0.99
# reward_scale : 1.0
# drawdown_call : 30
# target_call : 10
# dataset_stat : None
# episode_stat : None
# metadata : {}
# trial_stat : None
# trial_metadata : None
# portfolio_actions : ('hold', 'buy', 'sell', 'close')
# skip_frame : 1
# order_size : None
# initial_action : {'default_asset': 0}
# initial_portfolio_action : {'default_asset': 'hold'}
# episode_duration : {'days': 1, 'hours': 23, 'minutes': 55}
#
# Parameters [render]:
# render_state_as_image : True
# render_state_channel : 0
# render_size_human : (6, 3.5)
# render_size_state : (7, 3.5)
# render_size_episode : (12, 8)
# render_dpi : 75
# render_plotstyle : seaborn
# render_cmap : PRGn
# render_xlabel : Relative timesteps
# render_ylabel : Value
# render_title : local step: {}, state observation min: {:.4f}, max: {:.4f}
# render_boxtext : {'fontsize': 12, 'fontweight': 'bold', 'color': 'w', 'bbox': {'facecolor': 'k', 'alpha': 0.3, 'pad': 3}}
# plt_backend : Agg
# [2018-09-16 09:33:31.627795] INFO: BTgymAPIshell_0: Data domain `reset()` called prior to `reset_data()` with [possibly inconsistent] defaults.
# [2018-09-16 09:33:31.635461] NOTICE: BTgymDataServer_0: Initial global_time set to: 2016-01-03 17:01:00 / stamp: 1451869260.0
# [2018-09-16 09:33:31.645093] INFO: BTgymServer_0: Requesting new Trial sample with args: {'get_new': True, 'sample_type': 0, 'timestamp': None, 'b_alpha': 1, 'b_beta': 1}
# [2018-09-16 09:33:31.712686] INFO: SimpleDataSet_0: New sample id: <train_trial_w_0_num_0_at_2016-09-26>.
# [2018-09-16 09:33:31.764364] INFO: BTgymServer_0: Requesting episode from <train_trial_w_0_num_0_at_2016-09-26> with args: {'get_new': True, 'sample_type': 0, 'timestamp': 1451869260.0, 'b_alpha': 1, 'b_beta': 1}
# [2018-09-16 09:33:31.776551] INFO: Trial_0: New sample id: <train_episode_w_0_num_0_at_2016-09-26>.
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.010000000000000009
# INFO: [{'step': 1, 'time': datetime.datetime(2016, 9, 26, 0, 30), 'action': {'default_asset': 'hold'}, 'broker_message': '-', 'broker_cash': 100.0, 'broker_value': 100.0, 'drawdown': 0.0, 'max_drawdown': 0.0}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.010000000000000009
# INFO: [{'step': 2, 'time': datetime.datetime(2016, 9, 26, 0, 31), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 100.0, 'broker_value': 100.0, 'drawdown': 0.0, 'max_drawdown': 0.0}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.010000000000000009
# INFO: [{'step': 3, 'time': datetime.datetime(2016, 9, 26, 0, 32), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 100.0, 'broker_value': 100.0, 'drawdown': 0.0, 'max_drawdown': 0.0}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.012481162750001256
# INFO: [{'step': 4, 'time': datetime.datetime(2016, 9, 26, 0, 33), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12249, Cost: 11.2249, Comm: 0.0224', 'broker_cash': 100.0, 'broker_value': 100.0, 'drawdown': 0.0, 'max_drawdown': 0.0}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.01011106274999968
# INFO: [{'step': 5, 'time': datetime.datetime(2016, 9, 26, 0, 34), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 88.75265019999999, 'broker_value': 99.97995019999999, 'drawdown': 0.020049800000009554, 'max_drawdown': 0.020049800000009554}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.022608272999999922
# INFO: [{'step': 6, 'time': datetime.datetime(2016, 9, 26, 0, 35), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; SELL executed,\nPrice: 1.12261, Cost: 11.2249, Comm: 0.0225', 'broker_cash': 88.75265019999999, 'broker_value': 99.9788502, 'drawdown': 0.021149800000003438, 'max_drawdown': 0.021149800000003438}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.012722531250001128
# INFO: [{'step': 7, 'time': datetime.datetime(2016, 9, 26, 0, 36), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12267, Cost: 11.2267, Comm: 0.0225', 'broker_cash': 99.95629799999999, 'broker_value': 99.95629799999999, 'drawdown': 0.043702000000010344, 'max_drawdown': 0.043702000000010344}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.02283459619999876
# INFO: [{'step': 8, 'time': datetime.datetime(2016, 9, 26, 0, 37), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12267, Cost: 11.2267, Comm: 0.0225', 'broker_cash': 88.70714459999998, 'broker_value': 99.93394459999998, 'drawdown': 0.06605540000002463, 'max_drawdown': 0.06605540000002463}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.012615551449999544
# INFO: [{'step': 9, 'time': datetime.datetime(2016, 9, 26, 0, 38), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12259, Cost: 11.2259, Comm: 0.0225', 'broker_cash': 99.91139119999998, 'broker_value': 99.91139119999998, 'drawdown': 0.08860880000001714, 'max_drawdown': 0.08860880000001714}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.02267712160000128
# INFO: [{'step': 10, 'time': datetime.datetime(2016, 9, 26, 0, 39), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.
 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; BUY executed,\nPrice: 1.12286, Cost: 11.2286, Comm: 0.0225', 'broker_cash': 77.28035760000002, 'broker_value': 99.73775760000001, 'drawdown': 0.262242399999991, 'max_drawdown': 0.262242399999991}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.012676909100000786
# INFO: [{'step': 23, 'time': datetime.datetime(2016, 9, 26, 0, 52), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; SELL executed,\nPrice: 1.12279, Cost: 11.2277, Comm: 0.0225', 'broker_cash': 66.02930040000001, 'broker_value': 99.71360040000002, 'drawdown': 0.28639959999998155, 'max_drawdown': 0.28639959999998155}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.06547142619999897
# INFO: [{'step': 24, 'time': datetime.datetime(2016, 9, 26, 0, 53), 'action': {'default_asset': 'hold'}, 'broker_message': 'SELL executed,\nPrice: 1.12271, Cost: 22.4554, Comm: 0.0449', 'broker_cash': 77.23474460000001, 'broker_value': 99.68934460000001, 'drawdown': 0.3106553999999875, 'max_drawdown': 0.3106553999999875}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.009644036199999984
# INFO: [{'step': 25, 'time': datetime.datetime(2016, 9, 26, 0, 54), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 99.64403620000002, 'broker_value': 99.64403620000002, 'drawdown': 0.3559637999999836, 'max_drawdown': 0.3559637999999836}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.009644036199999984
# INFO: [{'step': 26, 'time': datetime.datetime(2016, 9, 26, 0, 55), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 99.64403620000002, 'broker_value': 99.64403620000002, 'drawdown': 0.3559637999999836, 'max_drawdown': 0.3559637999999836}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.01257144144999978
# INFO: [{'step': 27, 'time': datetime.datetime(2016, 9, 26, 0, 56), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12279, Cost: 11.2279, Comm: 0.0225', 'broker_cash': 99.64403620000002, 'broker_value': 99.64403620000002, 'drawdown': 0.3559637999999836, 'max_drawdown': 0.3559637999999836}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.012355974450001243
# INFO: [{'step': 28, 'time': datetime.datetime(2016, 9, 26, 0, 57), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12268, Cost: 11.2268, Comm: 0.0225', 'broker_cash': 88.39368040000001, 'broker_value': 99.62038040000002, 'drawdown': 0.37961959999998385, 'max_drawdown': 0.37961959999998385}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.0122293319500007
# INFO: [{'step': 29, 'time': datetime.datetime(2016, 9, 26, 0, 58), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12270, Cost: 11.2270, Comm: 0.0225', 'broker_cash': 77.1444268, 'broker_value': 99.5982268, 'drawdown': 0.40177319999999384, 'max_drawdown': 0.40177319999999384}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.04798962280000062
# INFO: [{'step': 30, 'time': datetime.datetime(2016, 9, 26, 0, 59), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; SELL executed,\nPrice: 1.12275, Cost: 33.6817, Comm: 0.0674', 'broker_cash': 65.8949728, 'broker_value': 99.5768728, 'drawdown': 0.42312719999999615, 'max_drawdown': 0.42312719999999615}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.009510107800000056
# INFO: [{'step': 31, 'time': datetime.datetime(2016, 9, 26, 1, 0), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 99.51010780000001, 'broker_value': 99.51010780000001, 'drawdown': 0.4898921999999857, 'max_drawdown': 0.4898921999999857}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.012313961050000334
# INFO: [{'step': 32, 'time': datetime.datetime(2016, 9, 26, 1, 1), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12287, Cost: 11.2287, Comm: 0.0225', 'broker_cash': 99.51010780000001, 'broker_value': 99.51010780000001, 'drawdown': 0.4898921999999857, 'max_drawdown': 0.4898921999999857}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.012248440050001717
# INFO: [{'step': 33, 'time': datetime.datetime(2016, 9, 26, 1, 2), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12284, Cost: 11.2284, Comm: 0.0225', 'broker_cash': 88.25895040000002, 'broker_value': 99.48745040000001, 'drawdown': 0.5125495999999856, 'max_drawdown': 0.5125495999999856}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0
]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.008968419000000005
# INFO: [{'step': 71, 'time': datetime.datetime(2016, 9, 26, 1, 40), 'action': {'default_asset': 'hold'}, 'broker_message': '-', 'broker_cash': 98.96841900000001, 'broker_value': 98.96841900000001, 'drawdown': 1.0315809999999885, 'max_drawdown': 1.0315809999999885}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.008968419000000005
# INFO: [{'step': 72, 'time': datetime.datetime(2016, 9, 26, 1, 41), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 98.96841900000001, 'broker_value': 98.96841900000001, 'drawdown': 1.0315809999999885, 'max_drawdown': 1.0315809999999885}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.011883845250001055
# INFO: [{'step': 73, 'time': datetime.datetime(2016, 9, 26, 1, 42), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; SELL executed,\nPrice: 1.12295, Cost: 11.2295, Comm: 0.0225', 'broker_cash': 98.96841900000001, 'broker_value': 98.96841900000001, 'drawdown': 1.0315809999999885, 'max_drawdown': 1.0315809999999885}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.022049624000000982
# INFO: [{'step': 74, 'time': datetime.datetime(2016, 9, 26, 1, 43), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12305, Cost: 11.2295, Comm: 0.0225', 'broker_cash': 87.71646000000001, 'broker_value': 98.94486, 'drawdown': 1.0551399999999944, 'max_drawdown': 1.0551399999999944}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.011701899249998184
# INFO: [{'step': 75, 'time': datetime.datetime(2016, 9, 26, 1, 44), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12299, Cost: 11.2299, Comm: 0.0225', 'broker_cash': 98.922499, 'broker_value': 98.922499, 'drawdown': 1.077500999999998, 'max_drawdown': 1.077500999999998}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.008993424250000055
# INFO: [{'step': 76, 'time': datetime.datetime(2016, 9, 26, 1, 45), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 87.67013920000001, 'broker_value': 98.90003920000001, 'drawdown': 1.099960799999991, 'max_drawdown': 1.099960799999991}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.02204026640000033
# INFO: [{'step': 77, 'time': datetime.datetime(2016, 9, 26, 1, 46), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; SELL executed,\nPrice: 1.12289, Cost: 11.2299, Comm: 0.0225', 'broker_cash': 87.67013920000001, 'broker_value': 98.89923920000001, 'drawdown': 1.100760799999989, 'max_drawdown': 1.100760799999989}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.011668084399998451
# INFO: [{'step': 78, 'time': datetime.datetime(2016, 9, 26, 1, 47), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; SELL executed,\nPrice: 1.12288, Cost: 11.2288, Comm: 0.0225', 'broker_cash': 98.8765814, 'broker_value': 98.8765814, 'drawdown': 1.1234185999999937, 'max_drawdown': 1.1234185999999937}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.011664686900001239
# INFO: [{'step': 79, 'time': datetime.datetime(2016, 9, 26, 1, 48), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12290, Cost: 11.2290, Comm: 0.0225', 'broker_cash': 87.62532380000002, 'broker_value': 98.85402380000002, 'drawdown': 1.1459761999999785, 'max_drawdown': 1.1459761999999785}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.011710563649999966
# INFO: [{'step': 80, 'time': datetime.datetime(2016, 9, 26, 1, 49), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12293, Cost: 11.2289, Comm: 0.0225', 'broker_cash': 76.37386580000002, 'broker_value': 98.83126580000001, 'drawdown': 1.1687341999999887, 'max_drawdown': 1.1687341999999887}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.032098002600000376
# INFO: [{'step': 81, 'time': datetime.datetime(2016, 9, 26, 1, 50), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12298, Cost: 11.2289, Comm: 0.0225', 'broker_cash': 87.57990720000002, 'broker_value': 98.80790720000002, 'drawdown': 1.1920927999999833, 'max_drawdown': 1.1920927999999833}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.008785447599999996
# INFO: [{'step': 82, 'time': datetime.datetime(2016, 9, 26, 1, 51), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 98.78544760000001, 'broker_value': 98.78544760000001, 'drawdown': 1.214552399999988, 'max_drawdown': 1.214552399999988}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.011403873849999217
# INFO: [{'step': 83, 'time': datetime.datetime(2016, 9, 26, 1, 52), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12295, Cost: 11.2295, Comm: 0.0225', 'broker_cash': 98.78544760000001, 'broker_value': 98.78544760000001, 'drawdown': 1.214552399999988, 'max_drawdown': 1.214552399999988}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.011377771600001968
# INFO: [{'step': 84, 'time': datetime.datetime(2016, 9, 26, 1, 53), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; BUY executed,\nPrice: 1.12309, Cost: 11.2309, Comm: 0.0225', 'broker_cash': 87.53348860000001, 'broker_value': 98.76428860000001, 'drawdown': 1.2357113999999854, 'max_drawdown': 1.2357113999999854}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.011512367600001247
# INFO: [{'step': 85, 'time': datetime.datetime(2016, 9, 26, 1, 54), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; SELL executed,\nPrice: 1.12316, Cost: 11.2302, Comm: 0.0225', 'broker_cash': 76.2801268, 'broker_value': 98.7431268, 'drawdown': 1.2568732000000011, 'max_drawdown': 1.2568732000000011}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.031171410999997828
# INFO: [{'step': 86, 'time': datetime.datetime(2016, 9, 26, 1, 55), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; SELL executed,\nPrice: 1.12313, Cost: 11.2302, Comm: 0.0225', 'broker_cash': 87.4892636, 'broker_value': 98.7206636, 'drawdown': 1.2793364000000054, 'max_drawdown': 1.2793364000000054}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.008698101000000014
# INFO: [{'step': 87, 'time': datetime.datetime(2016, 9, 26, 1, 56), 'action': {'default_asset': 'hold'}, 'broker_message': '-', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.008698101000000014
# INFO: [{'step': 88, 'time': datetime.datetime(2016, 9, 26, 1, 57), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.008698101000000014
# INFO: [{'step': 89, 'time': datetime.datetime(2016, 9, 26, 1, 58), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.008698101000000014
# INFO: [{'step': 90, 'time': datetime.datetime(2016, 9, 26, 1, 59), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.008698101000000014
# INFO: [{'step': 91, 'time': datetime.datetime(2016, 9, 26, 2, 0), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.008698101000000014
# INFO: [{'step': 92, 'time': datetime.datetime(2016, 9, 26, 2, 1), 'action': {'default_asset': 'hold'}, 'broker_message': '-', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.008698101000000014
# INFO: [{'step': 93, 'time': datetime.datetime(2016, 9, 26, 2, 2), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.011339594249999302
# INFO: [{'step': 94, 'time': datetime.datetime(2016, 9, 26, 2, 3), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12227, Cost: 11.2227, Comm: 0.0224', 'broker_cash': 98.69810100000001, 'broker_value': 98.69810100000001, 'drawdown': 1.3018989999999917, 'max_drawdown': 1.3018989999999917}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.021244022599999614
# INFO: [{'step': 95, 'time': datetime.datetime(2016, 9, 26, 2, 4), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12240, Cost: 11.2227, Comm: 0.0224', 'broker_cash': 87.45295560000001, 'broker_value': 98.6767556, 'drawdown': 1.323244399999993, 'max_drawdown': 1.323244399999993}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.011519295350001194
# INFO: [{'step': 96, 'time': datetime.datetime(2016, 9, 26, 2, 5), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12249, Cost: 11.2249, Comm: 0.0224', 'broker_cash': 98.65450760000002, 'broker_value': 98.65450760000002, 'drawdown': 1.3454923999999835, 'max_drawdown': 1.3454923999999835}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.008576070350001118
# INFO: [{'step': 97, 'time': datetime.datetime(2016, 9, 26, 2, 6), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 87.40715780000001, 'broker_value': 98.6313578, 'drawdown': 1.3686421999999965, 'max_drawdown': 1.3686421999999965}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.011354658849999543
# INFO: [{'step': 98, 'time': datetime.datetime(2016, 9, 26, 2, 7), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12246, Cost: 11.2246, Comm: 0.0224', 'broker_cash': 87.40715780000001, 'broker_value': 98.6317578, 'drawdown': 1.3682421999999974, 'max_drawdown': 1.3686421999999965}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.008870758849998507
# INFO: [{'step': 99, 'time': datetime.datetime(2016, 9, 26, 2, 8), 'action': {'default_asset': 'hold'}, 'broker_message': '-', 'broker_cash': 76.16010860000002, 'broker_value': 98.6097086, 'drawdown': 1.3902913999999953, 'max_drawdown': 1.3902913999999953}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.008422508850000303
# INFO: [{'step': 100, 'time': datetime.datetime(2016, 9, 26, 2, 9), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 76.16010860000002, 'broker_value': 98.60750860000002, 'drawdown': 1.392491399999983, 'max_drawdown': 1.392491399999983}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.03453794600000161
# INFO: [{'step': 101, 'time': datetime.datetime(2016, 9, 26, 2, 10), 'action': {'default_asset': 'hold'}, 'broker_message': 'SELL executed,\nPrice: 1.12244, Cost: 22.4495, Comm: 0.0449', 'broker_cash': 76.16010860000002, 'broker_value': 98.6089086, 'drawdown': 1.3910913999999934, 'max_drawdown': 1.392491399999983}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.008564011000000038
# INFO: [{'step': 102, 'time': datetime.datetime(2016, 9, 26, 2, 11), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 98.56401100000001, 'broker_value': 98.56401100000001, 'drawdown': 1.4359889999999922, 'max_drawdown': 1.4359889999999922}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.011478373000000893
# INFO: [{'step': 103, 'time': datetime.datetime(2016, 9, 26, 2, 12), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12252, Cost: 11.2252, Comm: 0.0225', 'broker_cash': 98.56401100000001, 'broker_value': 98.56401100000001, 'drawdown': 1.4359889999999922, 'max_drawdown': 1.4359889999999922}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.02167525799999873
# INFO: [{'step': 104, 'time': datetime.datetime(2016, 9, 26, 2, 13), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12263, Cost: 11.2252, Comm: 0.0225', 'broker_cash': 87.31636060000001, 'broker_value': 98.5404606, 'drawdown': 1.459539399999997, 'max_drawdown': 1.459539399999997}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.008518008000000021
# INFO: [{'step': 105, 'time': datetime.datetime(2016, 9, 26, 2, 14), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 98.51800800000001, 'broker_value': 98.51800800000001, 'drawdown': 1.481991999999991, 'max_drawdown': 1.481991999999991}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.011494591500002364
# INFO: [{'step': 106, 'time': datetime.datetime(2016, 9, 26, 2, 15), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12266, Cost: 11.2266, Comm: 0.0225', 'broker_cash': 98.51800800000001, 'broker_value': 98.51800800000001, 'drawdown': 1.481991999999991, 'max_drawdown': 1.481991999999991}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: -0.021743208399999218
# INFO: [{'step': 107, 'time': datetime.datetime(2016, 9, 26, 2, 16), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; BUY executed,\nPrice: 1.12282, Cost: 11.2266, Comm: 0.0225', 'broker_cash': 87.2689548, 'broker_value': 98.4939548, 'drawdown': 1.5060452000000026, 'max_drawdown': 1.5060452000000026}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.011151329399999176
# INFO: [{'step': 108, 'time': datetime.datetime(2016, 9, 26, 2, 17), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; SELL executed,\nPrice: 1.12276, Cost: 11.2276, Comm: 0.0225', 'broker_cash': 98.4714984, 'broker_value': 98.4714984, 'drawdown': 1.5285015999999985, 'max_drawdown': 1.5285015999999985}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.021158569600001495
# INFO: [{'step': 109, 'time': datetime.datetime(2016, 9, 26, 2, 18), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12268, Cost: 11.2276, Comm: 0.0225', 'broker_cash': 87.22144320000001, 'broker_value': 98.4498432, 'drawdown': 1.5501567999999963, 'max_drawdown': 1.5501567999999963}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: -0.011466046100000207
# INFO: [{'step': 110, 'time': datetime.datetime(2016, 9, 26, 2, 19), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12274, Cost: 11.2274, Comm: 0.0225', 'broker_cash': 98.4273896, 'broker_value': 98.4273896, 'drawdown': 1.572610400000002, 'max_drawdown': 1.572610400000002}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.011311107600000286
# INFO: [{'step': 111, 'time': datetime.datetime(2016, 9, 26, 2, 20), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12254, Cost: 11.2254, Comm: 0.0225', 'broker_cash': 87.17753479999999, 'broker_value': 98.4028348, 'drawdown': 1.5971652000000063, 'max_drawdown': 1.5971652000000063}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: -0.008466257600000438
# ...
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.016665448450000356
# INFO: [{'step': 1790, 'time': datetime.datetime(2016, 9, 27, 6, 27), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12433, Cost: 11.2433, Comm: 0.0225', 'broker_cash': 70.63845980000002, 'broker_value': 70.63845980000002, 'drawdown': 29.361540199999983, 'max_drawdown': 29.361540199999983}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.01690293295000018
# INFO: [{'step': 1791, 'time': datetime.datetime(2016, 9, 27, 6, 28), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12438, Cost: 11.2438, Comm: 0.0225', 'broker_cash': 59.37267320000002, 'broker_value': 70.61667320000002, 'drawdown': 29.383326799999978, 'max_drawdown': 29.383326799999978}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.016618320950000164
# INFO: [{'step': 1792, 'time': datetime.datetime(2016, 9, 27, 6, 29), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12452, Cost: 11.2452, Comm: 0.0225', 'broker_cash': 48.106385600000024, 'broker_value': 70.59658560000003, 'drawdown': 29.403414399999974, 'max_drawdown': 29.403414399999974}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.01662185844999979
# INFO: [{'step': 1793, 'time': datetime.datetime(2016, 9, 27, 6, 30), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; BUY executed,\nPrice: 1.12450, Cost: 11.2450, Comm: 0.0225', 'broker_cash': 36.838695200000025, 'broker_value': 70.57399520000003, 'drawdown': 29.426004799999973, 'max_drawdown': 29.426004799999973}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.01652662069999935
# INFO: [{'step': 1794, 'time': datetime.datetime(2016, 9, 27, 6, 31), 'action': {'default_asset': 'hold'}, 'broker_message': 'SELL executed,\nPrice: 1.12449, Cost: 11.2443, Comm: 0.0225', 'broker_cash': 25.571205200000023, 'broker_value': 70.55120520000003, 'drawdown': 29.448794799999973, 'max_drawdown': 29.448794799999973}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.019685970699999385
# INFO: [{'step': 1795, 'time': datetime.datetime(2016, 9, 27, 6, 32), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 36.79361540000002, 'broker_value': 70.52741540000002, 'drawdown': 29.472584599999976, 'max_drawdown': 29.472584599999976}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.016665857949999637
# INFO: [{'step': 1796, 'time': datetime.datetime(2016, 9, 27, 6, 33), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12449, Cost: 11.2443, Comm: 0.0225', 'broker_cash': 36.79361540000002, 'broker_value': 70.52891540000002, 'drawdown': 29.471084599999987, 'max_drawdown': 29.472584599999976}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.017276020950000207
# INFO: [{'step': 1797, 'time': datetime.datetime(2016, 9, 27, 6, 34), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12452, Cost: 11.2452, Comm: 0.0225', 'broker_cash': 48.01602560000002, 'broker_value': 70.50602560000002, 'drawdown': 29.493974399999985, 'max_drawdown': 29.493974399999985}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.037406088199998355
# INFO: [{'step': 1798, 'time': datetime.datetime(2016, 9, 27, 6, 35), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12470, Cost: 33.7339, Comm: 0.0675', 'broker_cash': 36.74833520000002, 'broker_value': 70.48783520000002, 'drawdown': 29.51216479999998, 'max_drawdown': 29.51216479999998}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.01641081505000092
# INFO: [{'step': 1799, 'time': datetime.datetime(2016, 9, 27, 6, 36), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12473, Cost: 11.2473, Comm: 0.0225', 'broker_cash': 70.42185320000003, 'broker_value': 70.42185320000003, 'drawdown': 29.57814679999997, 'max_drawdown': 29.57814679999997}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.01708714979999888
# INFO: [{'step': 1800, 'time': datetime.datetime(2016, 9, 27, 6, 37), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12439, Cost: 11.2439, Comm: 0.0225', 'broker_cash': 59.15205860000003, 'broker_value': 70.39625860000004, 'drawdown': 29.60374139999996, 'max_drawdown': 29.60374139999996}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.019561374800001172
# INFO: [{'step': 1801, 'time': datetime.datetime(2016, 9, 27, 6, 38), 'action': {'default_asset': 'hold'}, 'broker_message': '-', 'broker_cash': 47.885670800000035, 'broker_value': 70.37587080000003, 'drawdown': 29.62412919999997, 'max_drawdown': 29.62412919999997}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.02018087480000021
# INFO: [{'step': 1802, 'time': datetime.datetime(2016, 9, 27, 6, 39), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 47.885670800000035, 'broker_value': 70.37527080000004, 'drawdown': 29.624729199999962, 'max_drawdown': 29.624729199999962}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.005641183200000392
# INFO: [{'step': 1803, 'time': datetime.datetime(2016, 9, 27, 6, 40), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; SELL executed,\nPrice: 1.12469, Cost: 22.4912, Comm: 0.0450', 'broker_cash': 47.885670800000035, 'broker_value': 70.37967080000004, 'drawdown': 29.62032919999996, 'max_drawdown': 29.624729199999962}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.016881884299998203
# INFO: [{'step': 1804, 'time': datetime.datetime(2016, 9, 27, 6, 41), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12470, Cost: 11.2470, Comm: 0.0225', 'broker_cash': 70.33448320000004, 'broker_value': 70.33448320000004, 'drawdown': 29.665516799999963, 'max_drawdown': 29.665516799999963}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.006846394400000691
# INFO: [{'step': 1805, 'time': datetime.datetime(2016, 9, 27, 6, 42), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12468, Cost: 11.2470, Comm: 0.0225', 'broker_cash': 59.064989200000035, 'broker_value': 70.31198920000003, 'drawdown': 29.688010799999976, 'max_drawdown': 29.688010799999976}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.01971030439999999
# INFO: [{'step': 1806, 'time': datetime.datetime(2016, 9, 27, 6, 43), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 70.28969560000003, 'broker_value': 70.28969560000003, 'drawdown': 29.71030439999997, 'max_drawdown': 29.71030439999997}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.01971030439999999
# INFO: [{'step': 1807, 'time': datetime.datetime(2016, 9, 27, 6, 44), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 70.28969560000003, 'broker_value': 70.28969560000003, 'drawdown': 29.71030439999997, 'max_drawdown': 29.71030439999997}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.016901971400000475
# INFO: [{'step': 1808, 'time': datetime.datetime(2016, 9, 27, 6, 45), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; BUY executed,\nPrice: 1.12468, Cost: 11.2468, Comm: 0.0225', 'broker_cash': 70.28969560000003, 'broker_value': 70.28969560000003, 'drawdown': 29.71030439999997, 'max_drawdown': 29.71030439999997}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.006776811200000343
# INFO: [{'step': 1809, 'time': datetime.datetime(2016, 9, 27, 6, 46), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; SELL executed,\nPrice: 1.12466, Cost: 11.2468, Comm: 0.0225', 'broker_cash': 59.02040200000003, 'broker_value': 70.26700200000003, 'drawdown': 29.732997999999967, 'max_drawdown': 29.732997999999967}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.01699670770000097
# INFO: [{'step': 1810, 'time': datetime.datetime(2016, 9, 27, 6, 47), 'action': {'default_asset': 'hold'}, 'broker_message': 'SELL executed,\nPrice: 1.12466, Cost: 11.2466, Comm: 0.0225', 'broker_cash': 70.24450880000003, 'broker_value': 70.24450880000003, 'drawdown': 29.755491199999966, 'max_drawdown': 29.755491199999966}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.019647232699999052
# INFO: [{'step': 1811, 'time': datetime.datetime(2016, 9, 27, 6, 48), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 58.975415600000034, 'broker_value': 70.22221560000004, 'drawdown': 29.77778439999996, 'max_drawdown': 29.77778439999996}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.01670402595000056
# INFO: [{'step': 1812, 'time': datetime.datetime(2016, 9, 27, 6, 49), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; SELL executed,\nPrice: 1.12473, Cost: 11.2473, Comm: 0.0225', 'broker_cash': 58.975415600000034, 'broker_value': 70.22111560000003, 'drawdown': 29.778884399999967, 'max_drawdown': 29.778884399999967}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: -0.006694081999999307
# INFO: [{'step': 1813, 'time': datetime.datetime(2016, 9, 27, 6, 50), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12485, Cost: 22.4939, Comm: 0.0450', 'broker_cash': 47.705621000000036, 'broker_value': 70.19622100000004, 'drawdown': 29.803778999999963, 'max_drawdown': 29.803778999999963}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.01984857299999998
# INFO: [{'step': 1814, 'time': datetime.datetime(2016, 9, 27, 6, 51), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; -', 'broker_cash': 70.15142700000004, 'broker_value': 70.15142700000004, 'drawdown': 29.84857299999996, 'max_drawdown': 29.84857299999996}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.017052342749999793
# INFO: [{'step': 1815, 'time': datetime.datetime(2016, 9, 27, 6, 52), 'action': {'default_asset': 'hold'}, 'broker_message': 'BUY executed,\nPrice: 1.12479, Cost: 11.2479, Comm: 0.0225', 'broker_cash': 70.15142700000004, 'broker_value': 70.15142700000004, 'drawdown': 29.84857299999996, 'max_drawdown': 29.84857299999996}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.01983969274999981
# INFO: [{'step': 1816, 'time': datetime.datetime(2016, 9, 27, 6, 53), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; -', 'broker_cash': 58.88103120000004, 'broker_value': 70.12883120000004, 'drawdown': 29.871168799999964, 'max_drawdown': 29.871168799999964}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.006834328599999669
# INFO: [{'step': 1817, 'time': datetime.datetime(2016, 9, 27, 6, 54), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; SELL executed,\nPrice: 1.12474, Cost: 11.2479, Comm: 0.0225', 'broker_cash': 58.88103120000004, 'broker_value': 70.12853120000004, 'drawdown': 29.87146879999996, 'max_drawdown': 29.87146879999996}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.01989406360000001
# INFO: [{'step': 1818, 'time': datetime.datetime(2016, 9, 27, 6, 55), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 70.10593640000003, 'broker_value': 70.10593640000003, 'drawdown': 29.894063599999967, 'max_drawdown': 29.894063599999967}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.017147778850000787
# INFO: [{'step': 1819, 'time': datetime.datetime(2016, 9, 27, 6, 56), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12461, Cost: 11.2461, Comm: 0.0225', 'broker_cash': 70.10593640000003, 'broker_value': 70.10593640000003, 'drawdown': 29.894063599999967, 'max_drawdown': 29.894063599999967}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.006968532999998681
# INFO: [{'step': 1820, 'time': datetime.datetime(2016, 9, 27, 6, 57), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12461, Cost: 11.2461, Comm: 0.0225', 'broker_cash': 58.83734420000003, 'broker_value': 70.08374420000004, 'drawdown': 29.91625579999996, 'max_drawdown': 29.91625579999996}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.019939047999999904
# INFO: [{'step': 1821, 'time': datetime.datetime(2016, 9, 27, 6, 58), 'action': {'default_asset': 'sell'}, 'broker_message': 'new default_asset_SELL created; -', 'broker_cash': 70.06095200000003, 'broker_value': 70.06095200000003, 'drawdown': 29.93904799999997, 'max_drawdown': 29.93904799999997}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.01692021625000081
# INFO: [{'step': 1822, 'time': datetime.datetime(2016, 9, 27, 6, 59), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12473, Cost: 11.2473, Comm: 0.0225', 'broker_cash': 70.06095200000003, 'broker_value': 70.06095200000003, 'drawdown': 29.93904799999997, 'max_drawdown': 29.93904799999997}]
# ACTION: OrderedDict([('default_asset', 3)])
# REWARD: 0.006622715999998953
# INFO: [{'step': 1823, 'time': datetime.datetime(2016, 9, 27, 7, 0), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; BUY executed,\nPrice: 1.12492, Cost: 11.2473, Comm: 0.0225', 'broker_cash': 58.79115740000003, 'broker_value': 70.03655740000004, 'drawdown': 29.963442599999965, 'max_drawdown': 29.963442599999965}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.01799028909999677
# INFO: [{'step': 1824, 'time': datetime.datetime(2016, 9, 27, 7, 1), 'action': {'default_asset': 'close'}, 'broker_message': 'new default_asset_CLOSE created; BUY executed,\nPrice: 1.12490, Cost: 11.2490, Comm: 0.0225', 'broker_cash': 70.01405900000003, 'broker_value': 70.01405900000003, 'drawdown': 29.985940999999965, 'max_drawdown': 29.985940999999965}]
# ACTION: OrderedDict([('default_asset', 1)])
# REWARD: 0.008936799600000104
# INFO: [{'step': 1825, 'time': datetime.datetime(2016, 9, 27, 7, 2), 'action': {'default_asset': 'buy'}, 'broker_message': 'new default_asset_BUY created; SELL executed,\nPrice: 1.12473, Cost: 11.2490, Comm: 0.0225DRAWDOWN CALL', 'broker_cash': 58.74256100000003, 'broker_value': 69.98966100000003, 'drawdown': 30.010338999999973, 'max_drawdown': 30.010338999999973}]
# ACTION: OrderedDict([('default_asset', 2)])
# REWARD: 0.019435853050000278
# INFO: [{'step': 1826, 'time': datetime.datetime(2016, 9, 27, 7, 3), 'action': {'default_asset': 'buy'}, 'broker_message': 'CLOSE, DRAWDOWN CALL', 'broker_cash': 69.96736640000003, 'broker_value': 69.96736640000003, 'drawdown': 30.03263359999997, 'max_drawdown': 30.03263359999997}]
# ACTION: OrderedDict([('default_asset', 0)])
# REWARD: 0.009297994599999523
# INFO: [{'step': 1827, 'time': datetime.datetime(2016, 9, 27, 7, 4), 'action': {'default_asset': 'sell'}, 'broker_message': 'CLOSE, DRAWDOWN CALL', 'broker_cash': 58.697972600000035, 'broker_value': 69.94457260000004, 'drawdown': 30.055427399999957, 'max_drawdown': 30.055427399999957}]
# [2018-09-16 09:33:37.025485] INFO: BTgymServer_0: Exiting.
# [2018-09-16 09:33:37.050950] INFO: BTgymAPIshell_0: Exiting. Exit code: None
# [2018-09-16 09:33:37.052266] INFO: BTgymDataServer_0: {'ctrl': 'Exiting.'}
# [2018-09-16 09:33:37.064022] INFO: BTgymAPIshell_0: {'ctrl': 'Exiting.'} Exit code: None
# [2018-09-16 09:33:37.073997] INFO: BTgymAPIshell_0: Environment closed.

# %%
import itertools
import random
import os

import sys
sys.path.insert(0,'..')

import IPython.display as Display
import PIL.Image as Image


from gym import spaces
from btgym import BTgymEnv

def show_rendered_image(rgb_array):
    """
    Convert numpy array to RGB image using PILLOW and
    show it inline using IPykernel.
    """
    Display.display(Image.fromarray(rgb_array))

def render_all_modes(env):
    """
    Retrieve and show environment renderings
    for all supported modes.
    """
    for mode in env.metadata['render.modes']:
        print('[{}] mode:'.format(mode))
        show_rendered_image(env.render(mode))

def take_some_steps(env, some_steps):
    """Just does it. Acting randomly."""
    for step in range(some_steps):
        rnd_action = env.action_space.sample()
        o, r, d, i = env.step(rnd_action)
        if d:
            print('Episode finished,')
            break
    print(step+1, 'steps made.\n')
'''
env = BTgymEnv(
    filename='../examples/data/DAT_ASCII_EURUSD_M1_2016.csv',
    state_shape={'raw': spaces.Box(low=-100, high=100,shape=(30,4))},
    skip_frame=5,
    timeframe=1440,
    start_cash=100,
    render_ylabel='Price Lines',
    render_size_episode=(12,8),
    render_size_human=(8, 3.5),
    render_size_state=(10, 3.5),
    render_dpi=75,
    verbose=0,
)
'''

env = BTgymEnv(
    filename='./data/sh601318.csv',
    start_weekdays={0, 1, 2, 3, 4},
    episode_duration={'days': 90, 'hours': 0, 'minutes': 0},
    # Want to start every episode at the begiining of the day:
    start_00=True,
    time_gap={'days': 1},
    
    start_cash=100,
    
    render_ylabel='Price Lines',
    render_size_episode=(12,8),
    render_size_human=(8, 3.5),
    render_size_state=(10, 3.5),
    render_dpi=75,
    
    verbose=1,
)


o = env.reset()
take_some_steps(env, 10000)
render_all_modes(env)
# Out:
# [2018-09-17 09:26:15.972450] INFO: BTgymAPIshell_0: Base Dataset class used.
# [2018-09-17 09:26:15.973120] INFO: BTgymAPIshell_0: Connecting data_server...
# [2018-09-17 09:26:16.016988] INFO: BTgymDataServer_0: PID: 13581
# [2018-09-17 09:26:16.035708] INFO: SimpleDataSet_0: Loaded 2737 records from <./data/sh601318.csv>.
# [2018-09-17 09:26:16.102085] INFO: SimpleDataSet_0: Data summary:
#               open         high          low        close  volume
# count  2737.000000  2737.000000  2737.000000  2737.000000  2737.0
# mean     28.881692    29.366153    28.457366    28.903862     0.0
# std      14.418571    14.651215    14.196526    14.424894     0.0
# min       9.110000     9.390000     8.720000     9.110000     0.0
# 25%      18.600000    18.840000    18.380000    18.620000     0.0
# 50%      23.090000    23.530000    22.780000    23.130000     0.0
# 75%      33.860000    34.390000    33.570000    34.030000     0.0
# max      78.790000    79.750000    76.820000    77.280000     0.0
# [2018-09-17 09:26:17.019849] INFO: BTgymAPIshell_0: ...done.
# [2018-09-17 09:26:17.022263] INFO: BTgymAPIshell_0: Base Cerebro class used. Base Strategy class used.
# [2018-09-17 09:26:17.034306] INFO: BTgymAPIshell_0: Inferring `state[raw]` high/low values form dataset: 8.720000 / 79.750000.
# [2018-09-17 09:26:17.094794] INFO: BTgymServer_0: PID: 13596
# [2018-09-17 09:26:18.091601] INFO: BTgymAPIshell_0: Server started, pinging tcp://127.0.0.1:5500 ...
# [2018-09-17 09:26:18.094232] INFO: BTgymAPIshell_0: Server seems ready with response: <{'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}>
# [2018-09-17 09:26:18.095696] INFO: BTgymAPIshell_0: Environment is ready.
# [2018-09-17 09:26:18.099834] INFO: BTgymAPIshell_0: Data domain `reset()` called prior to `reset_data()` with [possibly inconsistent] defaults.
# [2018-09-17 09:26:18.103095] ERROR: SimpleDataSet_0: Train subset should contain at least one sample, got: train_set size: 2737 rows, sample_size: 129600 rows
# Traceback (most recent call last):
#   File "../btgym/datafeed/base.py", line 364, in _reset
#     assert self.train_num_records >= self.sample_num_records
# AssertionError
# Process BTgymDataFeedServer-1:
# Traceback (most recent call last):
#   File "../btgym/datafeed/base.py", line 364, in _reset
#     assert self.train_num_records >= self.sample_num_records
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/devhome/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "../btgym/dataserver.py", line 158, in run
#     self.dataset.reset(**kwargs)
#   File "../btgym/datafeed/base.py", line 315, in reset
#     self._reset(data_filename=data_filename, **kwargs)
#   File "../btgym/datafeed/base.py", line 371, in _reset
#     raise AssertionError
# AssertionError

# %%
import warnings
warnings.filterwarnings("ignore") # suppress h5py deprecation warning

import os
import backtrader as bt
import numpy as np
from gym import spaces

from btgym import BTgymEnv, BTgymDataset, BTgymRandomDataDomain
from btgym.algorithms import Launcher

from btgym.research.gps.aac import GuidedAAC
from btgym.research.gps.policy import GuidedPolicy_0_0
from btgym.research.gps.strategy import GuidedStrategy_0_0, ExpertObserver

# Set backtesting engine and parameters:

engine = bt.Cerebro()

engine.addstrategy(
    GuidedStrategy_0_0,
    drawdown_call=10, # max % to loose, in percent of initial cash
    target_call=10,  # max % to win, same
    skip_frame=10,
    gamma=0.99,
    state_ext_scale=np.linspace(4e3, 1e3, num=6),
    reward_scale=7,
    expert_config=  # see btgym.research.gps.oracle.Oracle class for details
        {
            'time_threshold': 5,
            'pips_threshold': 10, 
            'pips_scale': 1e-4,
            'kernel_size': 10,
            'kernel_stddev': 1,
        },
)

# Expert actions observer:
engine.addobserver(ExpertObserver)

# Set leveraged account:
engine.broker.setcash(2000)
engine.broker.setcommission(commission=0.0001, leverage=10.0) # commisssion to imitate spread
engine.addsizer(bt.sizers.SizerFix, stake=5000)  

# Data: uncomment to get up to six month of 1 minute bars:
data_m1_6_month = [
    './data/DAT_ASCII_EURUSD_M1_201701.csv',
    './data/DAT_ASCII_EURUSD_M1_201702.csv',
    './data/DAT_ASCII_EURUSD_M1_201703.csv',
    #'./data/DAT_ASCII_EURUSD_M1_201704.csv',
    #'./data/DAT_ASCII_EURUSD_M1_201705.csv',
    #'./data/DAT_ASCII_EURUSD_M1_201706.csv',
]

# Uncomment single choice of source file:
dataset = BTgymRandomDataDomain(  
    #filename=data_m1_6_month,
    #filename='./data/DAT_ASCII_EURUSD_M1_2016.csv', # full year
    #filename='./data/test_sine_1min_period256_delta0002.csv',  # simple sine 
    filename='./data/sh601318.csv',  # simple sine 

    trial_params=dict(
        start_weekdays={0, 1, 2, 3, 4, 5, 6},
        sample_duration={'days': 3, 'hours': 0, 'minutes': 0},
        start_00=False,
        time_gap={'days': 1, 'hours': 10},
        test_period={'days': 0, 'hours': 0, 'minutes': 0},
    ),
    episode_params=dict(
        start_weekdays={0, 1, 2, 3, 4, 5, 6},
        sample_duration={'days': 1, 'hours': 23, 'minutes': 50},
        start_00=False,
        time_gap={'days': 1, 'hours': 0},
    ),
)

env_config = dict(
    class_ref=BTgymEnv, 
    kwargs=dict(
        dataset=dataset,
        engine=engine,
        render_modes=['episode', 'human', 'external', 'internal'],
        render_state_as_image=True,
        render_ylabel='OHL_diff. / Internals',
        render_size_episode=(12,8),
        render_size_human=(9, 4),
        render_size_state=(11, 3),
        render_dpi=75,
        port=5000,
        data_port=4999,
        connect_timeout=90,
        verbose=0,
    )
)

cluster_config = dict(
    host='127.0.0.1',
    port=12230,
    num_workers=4,  # Set according CPU's available or so
    num_ps=1,
    num_envs=1,
    log_dir=os.path.expanduser('~/tmp/gps'),
)

policy_config = dict(
    class_ref=GuidedPolicy_0_0,
    kwargs={
        'lstm_layers': (256, 256),
        'lstm_2_init_period': 50,
        'conv_2d_layer_config': (
             (32, (3, 1), (2, 1)),
             (32, (3, 1), (2, 1)),
             (64, (3, 1), (2, 1)),
             (64, (3, 1), (2, 1))
         ),
        'encode_internal_state': False,
    }
)

trainer_config = dict(
    class_ref=GuidedAAC,
    kwargs=dict(
        opt_learn_rate=1e-4, # scalar or random log-uniform 
        opt_end_learn_rate=1e-5,
        opt_decay_steps=20*10**6,
        model_gamma=0.99,
        model_gae_lambda=1.0,
        model_beta=0.01, # Entropy reg, scalar or random log-uniform
        aac_lambda=1.0, # main a3c loss weight
        guided_lambda=1.0,  # Imitation loss weight
        guided_decay_steps=10*10**6,  # annealing guided_lambda to zero in 10M steps
        rollout_length=20,
        time_flat=True,
        use_value_replay=False,
        episode_train_test_cycle=[1,0],
        model_summary_freq=100,
        episode_summary_freq=5,
        env_render_freq=5,
    )
)

launcher = Launcher(
    cluster_config=cluster_config,
    env_config=env_config,
    trainer_config=trainer_config,
    policy_config=policy_config,
    test_mode=False,
    max_env_steps=100*10**6,
    root_random_seed=0,
    purge_previous=1,  # ask to override previously saved model and logs
    verbose=1,
)

# Train it:
launcher.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-abce849f0608> in <module>()
#       5 import backtrader as bt
#       6 import numpy as np
# ----> 7 from gym import spaces
#       8
#       9 from btgym import BTgymEnv, BTgymDataset, BTgymRandomDataDomain
#
# /devhome/anaconda3/lib/python3.6/site-packages/gym/__init__.py in <module>()
#       8 from gym.version import VERSION as __version__
#       9
# ---> 10 from gym.core import Env, GoalEnv, Space, Wrapper, ObservationWrapper, ActionWrapper, RewardWrapper
#      11 from gym.envs import make, spec
#      12 from gym import wrappers, spaces, logger
#
# /devhome/anaconda3/lib/python3.6/site-packages/gym/core.py in <module>()
#      10 # Env-related abstractions
#      11
# ---> 12 class Env(object):
#      13     """The main OpenAI Gym class. It encapsulates an environment with
#      14     arbitrary behind-the-scenes dynamics. An environment can be
#
# /devhome/anaconda3/lib/python3.6/site-packages/gym/core.py in Env()
#      38     # Set this in SOME subclasses
#      39     metadata = {'render.modes': []}
# ---> 40     reward_range = (-np.inf, np.inf)
#      41     spec = None
#      42
#
# AttributeError: module 'numpy' has no attribute 'inf'
